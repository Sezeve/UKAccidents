# %% [markdown]
# I will use several data sources to prepare the final dataset.
#
# First, I will take data on incidents involving cyclists in London from the
# https://bikedata.cyclestreets.net/#11.84/51.49989/-0.06585
#
# Here I select the London location and select Cyclists as participants in the incidents.
#
# Such a query gave me a dataset with 138 incidents for years 2000 - 2020, which I download in csv format.
#
# The dataset has data on:
#
# Timestamp
# Severity
# Number of Casualties
# Number of Vehicles
# Latitude
# Longitude
#
# I'm interested in trying Tableau tool for further visualisations, so incident coordinates are what I need.
#
# Also, I want to see what the weather was like on the days of the incidents.
# My large dataset for bicycle incidents in UK contains weather and road conditions.
#
# I'll try to get similar information for my London dataset.
#
# After exploring ways to take historical weather data from various APIs, this time I settled on a quick solution - I found a library that can pull and agrigate historical weather data from various sources.
#
# https://github.com/meteostat/meteostat-python
#
# I got a file with historical data from 2000 to 2020.
# I'm going to filter and transform the data to find weather conditions on the days of the London incidents to get more insights.

# %%
pip install meteostat
# Out:
# Requirement already satisfied: meteostat in /Users/kristina/opt/anaconda3/lib/python3.9/site-packages (1.6.5)
# Requirement already satisfied: pandas>=1.1 in /Users/kristina/opt/anaconda3/lib/python3.9/site-packages (from meteostat) (1.4.2)
# Requirement already satisfied: numpy in /Users/kristina/opt/anaconda3/lib/python3.9/site-packages (from meteostat) (1.21.5)
# Requirement already satisfied: pytz in /Users/kristina/opt/anaconda3/lib/python3.9/site-packages (from meteostat) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/kristina/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/kristina/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.1->meteostat) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily, Stations

# %%
import pandas as pd

# %%
# Set time period
start = datetime(2000, 3, 21)
end = datetime(2020, 12, 8)

# %%
# Create Point for London UK
London = Point(51.509865, -0.118092, 70)

# %%
# Get daily data for period
data = Daily(London, start, end)
data = data.fetch()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7568 entries, 2000-03-21 to 2020-12-08
# Freq: D
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tavg    7568 non-null   float64
#  1   tmin    7480 non-null   float64
#  2   tmax    7506 non-null   float64
#  3   prcp    6648 non-null   float64
#  4   snow    92 non-null     float64
#  5   wdir    7148 non-null   float64
#  6   wspd    7366 non-null   float64
#  7   wpgt    801 non-null    float64
#  8   pres    7150 non-null   float64
#  9   tsun    0 non-null      float64
# dtypes: float64(10)
# memory usage: 650.4 KB

# %% [markdown]
# Column	Description	Type
# station	The Meteostat ID of the weather station (only if query refers to multiple stations)	String
# time	The date	Datetime64
# tavg	The average air temperature in °C	Float64
# tmin	The minimum air temperature in °C	Float64
# tmax	The maximum air temperature in °C	Float64
# prcp	The daily precipitation total in mm	Float64
# snow	The snow depth in mm	Float64
# wdir	The average wind direction in degrees (°)	Float64
# wspd	The average wind speed in km/h	Float64
# wpgt	The peak wind gust in km/h	Float64
# pres	The average sea-level air pressure in hPa	Float64
# tsun	The daily sunshine total in minutes (m)	Float64

# %%
#save csv
data.to_csv('/Users/kristina/Documents/Velo_python/weather_london_data.csv')

# %%
#save all in dataframe
df_w = pd.read_csv('/Users/kristina/Documents/Velo_python/weather_london_data.csv')

# %%
#check 

df_w.info()
df_w.count()
df_w
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7568 entries, 0 to 7567
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    7568 non-null   object
#  1   tavg    7568 non-null   float64
#  2   tmin    7480 non-null   float64
#  3   tmax    7506 non-null   float64
#  4   prcp    6648 non-null   float64
#  5   snow    92 non-null     float64
#  6   wdir    7148 non-null   float64
#  7   wspd    7366 non-null   float64
#  8   wpgt    801 non-null    float64
#  9   pres    7150 non-null   float64
#  10  tsun    0 non-null      float64
# dtypes: float64(10), object(1)
# memory usage: 650.5+ KB
#             time  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  \
# 0     2000-03-21   8.3   4.4  13.7   NaN   NaN   86.0  10.2   NaN  1022.2
# 1     2000-03-22   8.3   2.8  15.8   NaN   NaN    NaN   1.0   NaN  1016.6
# 2     2000-03-23   9.8   4.3  14.4   NaN   NaN    NaN  11.1   NaN  1010.6
# 3     2000-03-24  10.1   6.9  14.2   2.8   NaN  206.0  12.7   NaN  1006.5
# 4     2000-03-25   8.3   5.5  11.5   3.0   NaN  215.0  13.9   NaN  1009.3
# ...          ...   ...   ...   ...   ...   ...    ...   ...   ...     ...
# 7563  2020-12-04   3.1   2.0   3.8  15.0   NaN  260.0  17.3  35.2   977.3
# 7564  2020-12-05   3.2   1.4   5.0   0.0   NaN  106.0  13.8  27.8   991.5
# 7565  2020-12-06   1.7   0.9   3.3   0.0   NaN   13.0  11.0  25.9  1001.8
# 7566  2020-12-07   0.8  -0.2   2.1   0.3   NaN   25.0   6.5  16.7   999.3
# 7567  2020-12-08   0.9  -0.5   2.3   3.3   NaN  270.0   6.1  18.5  1003.6
#
#       tsun
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 7563   NaN
# 7564   NaN
# 7565   NaN
# 7566   NaN
# 7567   NaN
#
# [7568 rows x 11 columns]

# %%
#пrename Time to Date
#convert Date into datetime 

df_w.rename(columns={'time':'Date'}, inplace=True)
df_w['Date'] = pd.to_datetime(df_w['Date'])
df_w
# Out:
#            Date  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# 0    2000-03-21   8.3   4.4  13.7   NaN   NaN   86.0  10.2   NaN  1022.2   NaN
# 1    2000-03-22   8.3   2.8  15.8   NaN   NaN    NaN   1.0   NaN  1016.6   NaN
# 2    2000-03-23   9.8   4.3  14.4   NaN   NaN    NaN  11.1   NaN  1010.6   NaN
# 3    2000-03-24  10.1   6.9  14.2   2.8   NaN  206.0  12.7   NaN  1006.5   NaN
# 4    2000-03-25   8.3   5.5  11.5   3.0   NaN  215.0  13.9   NaN  1009.3   NaN
# ...         ...   ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 7563 2020-12-04   3.1   2.0   3.8  15.0   NaN  260.0  17.3  35.2   977.3   NaN
# 7564 2020-12-05   3.2   1.4   5.0   0.0   NaN  106.0  13.8  27.8   991.5   NaN
# 7565 2020-12-06   1.7   0.9   3.3   0.0   NaN   13.0  11.0  25.9  1001.8   NaN
# 7566 2020-12-07   0.8  -0.2   2.1   0.3   NaN   25.0   6.5  16.7   999.3   NaN
# 7567 2020-12-08   0.9  -0.5   2.3   3.3   NaN  270.0   6.1  18.5  1003.6   NaN
#
# [7568 rows x 11 columns]

# %%
#set date as index

df_w.set_index('Date', inplace=True)
df_w.info()
df_w
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7568 entries, 2000-03-21 to 2020-12-08
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tavg    7568 non-null   float64
#  1   tmin    7480 non-null   float64
#  2   tmax    7506 non-null   float64
#  3   prcp    6648 non-null   float64
#  4   snow    92 non-null     float64
#  5   wdir    7148 non-null   float64
#  6   wspd    7366 non-null   float64
#  7   wpgt    801 non-null    float64
#  8   pres    7150 non-null   float64
#  9   tsun    0 non-null      float64
# dtypes: float64(10)
# memory usage: 650.4 KB
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# Date
# 2000-03-21   8.3   4.4  13.7   NaN   NaN   86.0  10.2   NaN  1022.2   NaN
# 2000-03-22   8.3   2.8  15.8   NaN   NaN    NaN   1.0   NaN  1016.6   NaN
# 2000-03-23   9.8   4.3  14.4   NaN   NaN    NaN  11.1   NaN  1010.6   NaN
# 2000-03-24  10.1   6.9  14.2   2.8   NaN  206.0  12.7   NaN  1006.5   NaN
# 2000-03-25   8.3   5.5  11.5   3.0   NaN  215.0  13.9   NaN  1009.3   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2020-12-04   3.1   2.0   3.8  15.0   NaN  260.0  17.3  35.2   977.3   NaN
# 2020-12-05   3.2   1.4   5.0   0.0   NaN  106.0  13.8  27.8   991.5   NaN
# 2020-12-06   1.7   0.9   3.3   0.0   NaN   13.0  11.0  25.9  1001.8   NaN
# 2020-12-07   0.8  -0.2   2.1   0.3   NaN   25.0   6.5  16.7   999.3   NaN
# 2020-12-08   0.9  -0.5   2.3   3.3   NaN  270.0   6.1  18.5  1003.6   NaN
#
# [7568 rows x 10 columns]

# %%
df_w
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# Date
# 2000-03-21   8.3   4.4  13.7   NaN   NaN   86.0  10.2   NaN  1022.2   NaN
# 2000-03-22   8.3   2.8  15.8   NaN   NaN    NaN   1.0   NaN  1016.6   NaN
# 2000-03-23   9.8   4.3  14.4   NaN   NaN    NaN  11.1   NaN  1010.6   NaN
# 2000-03-24  10.1   6.9  14.2   2.8   NaN  206.0  12.7   NaN  1006.5   NaN
# 2000-03-25   8.3   5.5  11.5   3.0   NaN  215.0  13.9   NaN  1009.3   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2020-12-04   3.1   2.0   3.8  15.0   NaN  260.0  17.3  35.2   977.3   NaN
# 2020-12-05   3.2   1.4   5.0   0.0   NaN  106.0  13.8  27.8   991.5   NaN
# 2020-12-06   1.7   0.9   3.3   0.0   NaN   13.0  11.0  25.9  1001.8   NaN
# 2020-12-07   0.8  -0.2   2.1   0.3   NaN   25.0   6.5  16.7   999.3   NaN
# 2020-12-08   0.9  -0.5   2.3   3.3   NaN  270.0   6.1  18.5  1003.6   NaN
#
# [7568 rows x 10 columns]

# %%
#take a file with London accidents with coordinates

w = pd.read_csv('/Users/kristina/Documents/Velo_python/collisions_London.csv')
w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Accident Index        138 non-null    object
#  1   Timestamp             138 non-null    object
#  2   severity              138 non-null    object
#  3   Casualties            138 non-null    object
#  4   Number of Casualties  138 non-null    int64
#  5   Number of Vehicles    138 non-null    int64
#  6   url                   138 non-null    object
#  7   apiUrl                138 non-null    object
#  8   Latitude              138 non-null    float64
#  9   Longitude             138 non-null    float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 10.9+ KB

# %%
#convert date in datetime and take only date (without time)


w['Date']= pd.to_datetime(w['Timestamp']).dt.date

# %%
#set date as Index

w.set_index('Date', inplace=True)

# %%
#sort dataframe on index

w = w.sort_values(by = 'Date')
df_w = df_w.sort_values(by = 'Date')

# %%
#merge two dataframes on dates

all_weather = w.merge(df_w, left_index = True, right_index = True)
all_weather
# Out:
#            Accident Index                     Timestamp severity Casualties  \
# Date
# 2000-03-21  200001CP00079       8:06am, 21st March 2000   slight    Cyclist
# 2000-03-21  200001CP00131       6:00pm, 21st March 2000   slight    Cyclist
# 2000-07-27  200001CP00264        5:58pm, 27th July 2000  serious    Cyclist
# 2000-08-09  200001CP00309       1:00pm, 9th August 2000   slight    Cyclist
# 2000-11-20  200001CP00438    6:15am, 20th November 2000   slight    Cyclist
# ...                   ...                           ...      ...        ...
# 2019-12-06  2019480951155     6:30pm, 6th December 2019   slight    Cyclist
# 2019-12-30  2019480932151    3:28pm, 30th December 2019  serious    Cyclist
# 2020-09-28  2020480990431  12:10pm, 28th September 2020   slight    Cyclist
# 2020-10-02  2020480992250      7:16am, 2nd October 2020  serious    Cyclist
# 2020-12-08  2020481013284     9:30pm, 8th December 2020   slight    Cyclist
#
#             Number of Casualties  Number of Vehicles  \
# Date
# 2000-03-21                     1                   2
# 2000-03-21                     1                   2
# 2000-07-27                     1                   1
# 2000-08-09                     1                   2
# 2000-11-20                     1                   2
# ...                          ...                 ...
# 2019-12-06                     1                   2
# 2019-12-30                     1                   2
# 2020-09-28                     1                   2
# 2020-10-02                     1                   2
# 2020-12-08                     1                   2
#
#                                                           url  \
# Date
# 2000-03-21  https://www.cyclestreets.net/collisions/report...
# 2000-03-21  https://www.cyclestreets.net/collisions/report...
# 2000-07-27  https://www.cyclestreets.net/collisions/report...
# 2000-08-09  https://www.cyclestreets.net/collisions/report...
# 2000-11-20  https://www.cyclestreets.net/collisions/report...
# ...                                                       ...
# 2019-12-06  https://www.cyclestreets.net/collisions/report...
# 2019-12-30  https://www.cyclestreets.net/collisions/report...
# 2020-09-28  https://www.cyclestreets.net/collisions/report...
# 2020-10-02  https://www.cyclestreets.net/collisions/report...
# 2020-12-08  https://www.cyclestreets.net/collisions/report...
#
#                                                        apiUrl   Latitude  \
# Date
# 2000-03-21  https://api.cyclestreets.net/v2/collisions.loc...  51.510986
# 2000-03-21  https://api.cyclestreets.net/v2/collisions.loc...  51.511196
# 2000-07-27  https://api.cyclestreets.net/v2/collisions.loc...  51.511908
# 2000-08-09  https://api.cyclestreets.net/v2/collisions.loc...  51.510995
# 2000-11-20  https://api.cyclestreets.net/v2/collisions.loc...  51.511470
# ...                                                       ...        ...
# 2019-12-06  https://api.cyclestreets.net/v2/collisions.loc...  51.511124
# 2019-12-30  https://api.cyclestreets.net/v2/collisions.loc...  51.511032
# 2020-09-28  https://api.cyclestreets.net/v2/collisions.loc...  51.512006
# 2020-10-02  https://api.cyclestreets.net/v2/collisions.loc...  51.511075
# 2020-12-08  https://api.cyclestreets.net/v2/collisions.loc...  51.511008
#
#             Longitude  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt  \
# Date
# 2000-03-21  -0.102536   8.3   4.4  13.7   NaN   NaN   86.0  10.2   NaN
# 2000-03-21  -0.104401   8.3   4.4  13.7   NaN   NaN   86.0  10.2   NaN
# 2000-07-27  -0.103939  19.3  16.0  23.8   NaN   NaN  228.0  10.0   NaN
# 2000-08-09  -0.103112  19.1  16.0  22.7   NaN   NaN  200.0  11.6   NaN
# 2000-11-20  -0.104678   5.8   4.0   6.9   NaN   NaN  221.0   9.5   NaN
# ...               ...   ...   ...   ...   ...   ...    ...   ...   ...
# 2019-12-06  -0.107082   9.2   7.1  10.8   1.5   NaN  245.0  25.2  46.3
# 2019-12-30  -0.103036   5.8   3.7   9.5   0.0   NaN  223.0  11.7  25.9
# 2020-09-28  -0.104307  11.7   8.4  15.8   0.0   NaN  299.0  13.7  29.6
# 2020-10-02  -0.102386  11.1   9.9  11.8   3.6   NaN   68.0  19.8  40.8
# 2020-12-08  -0.103210   0.9  -0.5   2.3   3.3   NaN  270.0   6.1  18.5
#
#               pres  tsun
# Date
# 2000-03-21  1022.2   NaN
# 2000-03-21  1022.2   NaN
# 2000-07-27  1012.5   NaN
# 2000-08-09  1018.6   NaN
# 2000-11-20   995.6   NaN
# ...            ...   ...
# 2019-12-06  1006.0   NaN
# 2019-12-30  1029.4   NaN
# 2020-09-28  1013.4   NaN
# 2020-10-02   988.7   NaN
# 2020-12-08  1003.6   NaN
#
# [138 rows x 20 columns]

# %%
#rename columns

all_weather.rename(columns={'tmax':'Max temperature C',
                            'prcp':'Daily precipitation mm',
                            'snow':'Snow depth mm',
                            'wspd':'Wind speed km/h',
                            'wpgt': 'Peak wind gust in km/h'
                           }, inplace=True)

# %%
all_weather
# Out:
#                      Timestamp      Month        Day  index  \
# Date
# 2000-03-21 2000-03-21 08:06:00      March    Tuesday      0
# 2000-03-21 2000-03-21 18:00:00      March    Tuesday      0
# 2000-07-27 2000-07-27 17:58:00       July   Thursday    128
# 2000-08-09 2000-08-09 13:00:00     August  Wednesday    141
# 2000-11-20 2000-11-20 06:15:00   November     Monday    244
# ...                        ...        ...        ...    ...
# 2019-12-06 2019-12-06 18:30:00   December     Friday   7199
# 2019-12-30 2019-12-30 15:28:00   December     Monday   7223
# 2020-09-28 2020-09-28 12:10:00  September     Monday   7496
# 2020-10-02 2020-10-02 07:16:00    October     Friday   7500
# 2020-12-08 2020-12-08 21:30:00   December    Tuesday   7567
#
#             Max temperature C  Daily precipitation mm  Snow depth mm  \
# Date
# 2000-03-21               13.7                     NaN            NaN
# 2000-03-21               13.7                     NaN            NaN
# 2000-07-27               23.8                     NaN            NaN
# 2000-08-09               22.7                     NaN            NaN
# 2000-11-20                6.9                     NaN            NaN
# ...                       ...                     ...            ...
# 2019-12-06               10.8                     1.5            NaN
# 2019-12-30                9.5                     0.0            NaN
# 2020-09-28               15.8                     0.0            NaN
# 2020-10-02               11.8                     3.6            NaN
# 2020-12-08                2.3                     3.3            NaN
#
#             Wind speed km/h  Peak wind gust in km/h
# Date
# 2000-03-21             10.2                     NaN
# 2000-03-21             10.2                     NaN
# 2000-07-27             10.0                     NaN
# 2000-08-09             11.6                     NaN
# 2000-11-20              9.5                     NaN
# ...                     ...                     ...
# 2019-12-06             25.2                    46.3
# 2019-12-30             11.7                    25.9
# 2020-09-28             13.7                    29.6
# 2020-10-02             19.8                    40.8
# 2020-12-08              6.1                    18.5
#
# [138 rows x 9 columns]

# %% [markdown]
# Weather conditions I need to get: Rain, Snow, Fog, Clear, Clear and windy, Rain and windy, Snow and windy

# %%
#I put everything into csv

all_weather.to_csv('/Users/kristina/Documents/Velo_python/allweather_data.csv')

# %%
df = pd.read_csv('/Users/kristina/Documents/Velo_python/allweather_data.csv')

# %%
df
# Out:
#            Date Accident Index                     Timestamp severity  \
# 0    2000-03-21  200001CP00079       8:06am, 21st March 2000   slight
# 1    2000-03-21  200001CP00131       6:00pm, 21st March 2000   slight
# 2    2000-07-27  200001CP00264        5:58pm, 27th July 2000  serious
# 3    2000-08-09  200001CP00309       1:00pm, 9th August 2000   slight
# 4    2000-11-20  200001CP00438    6:15am, 20th November 2000   slight
# ..          ...            ...                           ...      ...
# 133  2019-12-06  2019480951155     6:30pm, 6th December 2019   slight
# 134  2019-12-30  2019480932151    3:28pm, 30th December 2019  serious
# 135  2020-09-28  2020480990431  12:10pm, 28th September 2020   slight
# 136  2020-10-02  2020480992250      7:16am, 2nd October 2020  serious
# 137  2020-12-08  2020481013284     9:30pm, 8th December 2020   slight
#
#     Casualties  Number of Casualties  Number of Vehicles  \
# 0      Cyclist                     1                   2
# 1      Cyclist                     1                   2
# 2      Cyclist                     1                   1
# 3      Cyclist                     1                   2
# 4      Cyclist                     1                   2
# ..         ...                   ...                 ...
# 133    Cyclist                     1                   2
# 134    Cyclist                     1                   2
# 135    Cyclist                     1                   2
# 136    Cyclist                     1                   2
# 137    Cyclist                     1                   2
#
#                                                    url  \
# 0    https://www.cyclestreets.net/collisions/report...
# 1    https://www.cyclestreets.net/collisions/report...
# 2    https://www.cyclestreets.net/collisions/report...
# 3    https://www.cyclestreets.net/collisions/report...
# 4    https://www.cyclestreets.net/collisions/report...
# ..                                                 ...
# 133  https://www.cyclestreets.net/collisions/report...
# 134  https://www.cyclestreets.net/collisions/report...
# 135  https://www.cyclestreets.net/collisions/report...
# 136  https://www.cyclestreets.net/collisions/report...
# 137  https://www.cyclestreets.net/collisions/report...
#
#                                                 apiUrl   Latitude  ...  tavg  \
# 0    https://api.cyclestreets.net/v2/collisions.loc...  51.510986  ...   8.3
# 1    https://api.cyclestreets.net/v2/collisions.loc...  51.511196  ...   8.3
# 2    https://api.cyclestreets.net/v2/collisions.loc...  51.511908  ...  19.3
# 3    https://api.cyclestreets.net/v2/collisions.loc...  51.510995  ...  19.1
# 4    https://api.cyclestreets.net/v2/collisions.loc...  51.511470  ...   5.8
# ..                                                 ...        ...  ...   ...
# 133  https://api.cyclestreets.net/v2/collisions.loc...  51.511124  ...   9.2
# 134  https://api.cyclestreets.net/v2/collisions.loc...  51.511032  ...   5.8
# 135  https://api.cyclestreets.net/v2/collisions.loc...  51.512006  ...  11.7
# 136  https://api.cyclestreets.net/v2/collisions.loc...  51.511075  ...  11.1
# 137  https://api.cyclestreets.net/v2/collisions.loc...  51.511008  ...   0.9
#
#      tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# 0     4.4  13.7   NaN   NaN   86.0  10.2   NaN  1022.2   NaN
# 1     4.4  13.7   NaN   NaN   86.0  10.2   NaN  1022.2   NaN
# 2    16.0  23.8   NaN   NaN  228.0  10.0   NaN  1012.5   NaN
# 3    16.0  22.7   NaN   NaN  200.0  11.6   NaN  1018.6   NaN
# 4     4.0   6.9   NaN   NaN  221.0   9.5   NaN   995.6   NaN
# ..    ...   ...   ...   ...    ...   ...   ...     ...   ...
# 133   7.1  10.8   1.5   NaN  245.0  25.2  46.3  1006.0   NaN
# 134   3.7   9.5   0.0   NaN  223.0  11.7  25.9  1029.4   NaN
# 135   8.4  15.8   0.0   NaN  299.0  13.7  29.6  1013.4   NaN
# 136   9.9  11.8   3.6   NaN   68.0  19.8  40.8   988.7   NaN
# 137  -0.5   2.3   3.3   NaN  270.0   6.1  18.5  1003.6   NaN
#
# [138 rows x 21 columns]

# %%
#create an empty column for weather conditions


df["Weather_conditions"] = ""

# %%
#I rename columns with dictionary

df.rename(columns={'tmax':'Max temperature C',
                   'severity':'Severity',
                   'tmin':'Min temperature C',
                            'prcp':'Daily precipitation mm',
                            'snow':'Snow depth mm',
                            'wspd':'Wind speed kmh',
                            'wpgt': 'Peak wind gust in kmh'
                           }, inplace=True)

# %%
df
# Out:
#            Date Accident Index                     Timestamp Severity  \
# 0    2000-03-21  200001CP00079       8:06am, 21st March 2000   slight
# 1    2000-03-21  200001CP00131       6:00pm, 21st March 2000   slight
# 2    2000-07-27  200001CP00264        5:58pm, 27th July 2000  serious
# 3    2000-08-09  200001CP00309       1:00pm, 9th August 2000   slight
# 4    2000-11-20  200001CP00438    6:15am, 20th November 2000   slight
# ..          ...            ...                           ...      ...
# 133  2019-12-06  2019480951155     6:30pm, 6th December 2019   slight
# 134  2019-12-30  2019480932151    3:28pm, 30th December 2019  serious
# 135  2020-09-28  2020480990431  12:10pm, 28th September 2020   slight
# 136  2020-10-02  2020480992250      7:16am, 2nd October 2020  serious
# 137  2020-12-08  2020481013284     9:30pm, 8th December 2020   slight
#
#     Casualties  Number of Casualties  Number of Vehicles  \
# 0      Cyclist                     1                   2
# 1      Cyclist                     1                   2
# 2      Cyclist                     1                   1
# 3      Cyclist                     1                   2
# 4      Cyclist                     1                   2
# ..         ...                   ...                 ...
# 133    Cyclist                     1                   2
# 134    Cyclist                     1                   2
# 135    Cyclist                     1                   2
# 136    Cyclist                     1                   2
# 137    Cyclist                     1                   2
#
#                                                    url  \
# 0    https://www.cyclestreets.net/collisions/report...
# 1    https://www.cyclestreets.net/collisions/report...
# 2    https://www.cyclestreets.net/collisions/report...
# 3    https://www.cyclestreets.net/collisions/report...
# 4    https://www.cyclestreets.net/collisions/report...
# ..                                                 ...
# 133  https://www.cyclestreets.net/collisions/report...
# 134  https://www.cyclestreets.net/collisions/report...
# 135  https://www.cyclestreets.net/collisions/report...
# 136  https://www.cyclestreets.net/collisions/report...
# 137  https://www.cyclestreets.net/collisions/report...
#
#                                                 apiUrl   Latitude  ...  \
# 0    https://api.cyclestreets.net/v2/collisions.loc...  51.510986  ...
# 1    https://api.cyclestreets.net/v2/collisions.loc...  51.511196  ...
# 2    https://api.cyclestreets.net/v2/collisions.loc...  51.511908  ...
# 3    https://api.cyclestreets.net/v2/collisions.loc...  51.510995  ...
# 4    https://api.cyclestreets.net/v2/collisions.loc...  51.511470  ...
# ..                                                 ...        ...  ...
# 133  https://api.cyclestreets.net/v2/collisions.loc...  51.511124  ...
# 134  https://api.cyclestreets.net/v2/collisions.loc...  51.511032  ...
# 135  https://api.cyclestreets.net/v2/collisions.loc...  51.512006  ...
# 136  https://api.cyclestreets.net/v2/collisions.loc...  51.511075  ...
# 137  https://api.cyclestreets.net/v2/collisions.loc...  51.511008  ...
#
#      Min temperature C  Max temperature C  Daily precipitation mm  \
# 0                  4.4               13.7                     NaN
# 1                  4.4               13.7                     NaN
# 2                 16.0               23.8                     NaN
# 3                 16.0               22.7                     NaN
# 4                  4.0                6.9                     NaN
# ..                 ...                ...                     ...
# 133                7.1               10.8                     1.5
# 134                3.7                9.5                     0.0
# 135                8.4               15.8                     0.0
# 136                9.9               11.8                     3.6
# 137               -0.5                2.3                     3.3
#
#      Snow depth mm   wdir  Wind speed kmh  Peak wind gust in kmh    pres  \
# 0              NaN   86.0            10.2                    NaN  1022.2
# 1              NaN   86.0            10.2                    NaN  1022.2
# 2              NaN  228.0            10.0                    NaN  1012.5
# 3              NaN  200.0            11.6                    NaN  1018.6
# 4              NaN  221.0             9.5                    NaN   995.6
# ..             ...    ...             ...                    ...     ...
# 133            NaN  245.0            25.2                   46.3  1006.0
# 134            NaN  223.0            11.7                   25.9  1029.4
# 135            NaN  299.0            13.7                   29.6  1013.4
# 136            NaN   68.0            19.8                   40.8   988.7
# 137            NaN  270.0             6.1                   18.5  1003.6
#
#      tsun  Weather_conditions
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...                 ...
# 133   NaN
# 134   NaN
# 135   NaN
# 136   NaN
# 137   NaN
#
# [138 rows x 22 columns]

# %%
#rename all columns with _

df = df.rename(columns=lambda col: col.replace(" ", "_"))

# %%
df
# Out:
#            Date Accident_Index                     Timestamp Severity  \
# 0    2000-03-21  200001CP00079       8:06am, 21st March 2000   slight
# 1    2000-03-21  200001CP00131       6:00pm, 21st March 2000   slight
# 2    2000-07-27  200001CP00264        5:58pm, 27th July 2000  serious
# 3    2000-08-09  200001CP00309       1:00pm, 9th August 2000   slight
# 4    2000-11-20  200001CP00438    6:15am, 20th November 2000   slight
# ..          ...            ...                           ...      ...
# 133  2019-12-06  2019480951155     6:30pm, 6th December 2019   slight
# 134  2019-12-30  2019480932151    3:28pm, 30th December 2019  serious
# 135  2020-09-28  2020480990431  12:10pm, 28th September 2020   slight
# 136  2020-10-02  2020480992250      7:16am, 2nd October 2020  serious
# 137  2020-12-08  2020481013284     9:30pm, 8th December 2020   slight
#
#     Casualties  Number_of_Casualties  Number_of_Vehicles  \
# 0      Cyclist                     1                   2
# 1      Cyclist                     1                   2
# 2      Cyclist                     1                   1
# 3      Cyclist                     1                   2
# 4      Cyclist                     1                   2
# ..         ...                   ...                 ...
# 133    Cyclist                     1                   2
# 134    Cyclist                     1                   2
# 135    Cyclist                     1                   2
# 136    Cyclist                     1                   2
# 137    Cyclist                     1                   2
#
#                                                    url  \
# 0    https://www.cyclestreets.net/collisions/report...
# 1    https://www.cyclestreets.net/collisions/report...
# 2    https://www.cyclestreets.net/collisions/report...
# 3    https://www.cyclestreets.net/collisions/report...
# 4    https://www.cyclestreets.net/collisions/report...
# ..                                                 ...
# 133  https://www.cyclestreets.net/collisions/report...
# 134  https://www.cyclestreets.net/collisions/report...
# 135  https://www.cyclestreets.net/collisions/report...
# 136  https://www.cyclestreets.net/collisions/report...
# 137  https://www.cyclestreets.net/collisions/report...
#
#                                                 apiUrl   Latitude  ...  \
# 0    https://api.cyclestreets.net/v2/collisions.loc...  51.510986  ...
# 1    https://api.cyclestreets.net/v2/collisions.loc...  51.511196  ...
# 2    https://api.cyclestreets.net/v2/collisions.loc...  51.511908  ...
# 3    https://api.cyclestreets.net/v2/collisions.loc...  51.510995  ...
# 4    https://api.cyclestreets.net/v2/collisions.loc...  51.511470  ...
# ..                                                 ...        ...  ...
# 133  https://api.cyclestreets.net/v2/collisions.loc...  51.511124  ...
# 134  https://api.cyclestreets.net/v2/collisions.loc...  51.511032  ...
# 135  https://api.cyclestreets.net/v2/collisions.loc...  51.512006  ...
# 136  https://api.cyclestreets.net/v2/collisions.loc...  51.511075  ...
# 137  https://api.cyclestreets.net/v2/collisions.loc...  51.511008  ...
#
#      Min_temperature_C  Max_temperature_C  Daily_precipitation_mm  \
# 0                  4.4               13.7                     NaN
# 1                  4.4               13.7                     NaN
# 2                 16.0               23.8                     NaN
# 3                 16.0               22.7                     NaN
# 4                  4.0                6.9                     NaN
# ..                 ...                ...                     ...
# 133                7.1               10.8                     1.5
# 134                3.7                9.5                     0.0
# 135                8.4               15.8                     0.0
# 136                9.9               11.8                     3.6
# 137               -0.5                2.3                     3.3
#
#      Snow_depth_mm   wdir  Wind_speed_kmh  Peak_wind_gust_in_kmh    pres  \
# 0              NaN   86.0            10.2                    NaN  1022.2
# 1              NaN   86.0            10.2                    NaN  1022.2
# 2              NaN  228.0            10.0                    NaN  1012.5
# 3              NaN  200.0            11.6                    NaN  1018.6
# 4              NaN  221.0             9.5                    NaN   995.6
# ..             ...    ...             ...                    ...     ...
# 133            NaN  245.0            25.2                   46.3  1006.0
# 134            NaN  223.0            11.7                   25.9  1029.4
# 135            NaN  299.0            13.7                   29.6  1013.4
# 136            NaN   68.0            19.8                   40.8   988.7
# 137            NaN  270.0             6.1                   18.5  1003.6
#
#      tsun  Weather_conditions
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...                 ...
# 133   NaN
# 134   NaN
# 135   NaN
# 136   NaN
# 137   NaN
#
# [138 rows x 22 columns]

# %%
#drop columns

df.drop(columns =['Accident_Index', 'Casualties', 'url', 'apiUrl', 'wdir', 'pres', 'tsun'], axis = 1)
# Out:
#            Date                     Timestamp Severity  Number_of_Casualties  \
# 0    2000-03-21       8:06am, 21st March 2000   Slight                     1
# 1    2000-03-21       6:00pm, 21st March 2000   Slight                     1
# 2    2000-07-27        5:58pm, 27th July 2000  Serious                     1
# 3    2000-08-09       1:00pm, 9th August 2000   Slight                     1
# 4    2000-11-20    6:15am, 20th November 2000   Slight                     1
# ..          ...                           ...      ...                   ...
# 133  2019-12-06     6:30pm, 6th December 2019   Slight                     1
# 134  2019-12-30    3:28pm, 30th December 2019  Serious                     1
# 135  2020-09-28  12:10pm, 28th September 2020   Slight                     1
# 136  2020-10-02      7:16am, 2nd October 2020  Serious                     1
# 137  2020-12-08     9:30pm, 8th December 2020   Slight                     1
#
#      Number_of_Vehicles   Latitude  Longitude  tavg  Min_temperature_C  \
# 0                     2  51.510986  -0.102536   8.3                4.4
# 1                     2  51.511196  -0.104401   8.3                4.4
# 2                     1  51.511908  -0.103939  19.3               16.0
# 3                     2  51.510995  -0.103112  19.1               16.0
# 4                     2  51.511470  -0.104678   5.8                4.0
# ..                  ...        ...        ...   ...                ...
# 133                   2  51.511124  -0.107082   9.2                7.1
# 134                   2  51.511032  -0.103036   5.8                3.7
# 135                   2  51.512006  -0.104307  11.7                8.4
# 136                   2  51.511075  -0.102386  11.1                9.9
# 137                   2  51.511008  -0.103210   0.9               -0.5
#
#      Max_temperature_C  Daily_precipitation_mm  Snow_depth_mm  Wind_speed_kmh  \
# 0                 13.7                     NaN            NaN            10.2
# 1                 13.7                     NaN            NaN            10.2
# 2                 23.8                     NaN            NaN            10.0
# 3                 22.7                     NaN            NaN            11.6
# 4                  6.9                     NaN            NaN             9.5
# ..                 ...                     ...            ...             ...
# 133               10.8                     1.5            NaN            25.2
# 134                9.5                     0.0            NaN            11.7
# 135               15.8                     0.0            NaN            13.7
# 136               11.8                     3.6            NaN            19.8
# 137                2.3                     3.3            NaN             6.1
#
#      Peak_wind_gust_in_kmh Weather_conditions
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ..                     ...                ...
# 133                   46.3
# 134                   25.9
# 135                   29.6
# 136                   40.8
# 137                   18.5
#
# [138 rows x 15 columns]

# %%
#Create a dictionary according info in my big dataset, I want everything to be consistent in both datasets

severity = {
            'slight':'Slight', 'serious':'Serious', 'fatal':'Fatal'}

# %%
#rename coulmn
df['Severity'] = df['Severity'].apply(lambda x: severity[x])

# %%
#drop-off columns

df.drop(columns =['Accident_Index', 'Casualties', 'url', 'apiUrl', 'wdir', 'pres', 'tsun'], axis = 1)
# Out:
#            Date                     Timestamp Severity  Number_of_Casualties  \
# 0    2000-03-21       8:06am, 21st March 2000   Slight                     1
# 1    2000-03-21       6:00pm, 21st March 2000   Slight                     1
# 2    2000-07-27        5:58pm, 27th July 2000  Serious                     1
# 3    2000-08-09       1:00pm, 9th August 2000   Slight                     1
# 4    2000-11-20    6:15am, 20th November 2000   Slight                     1
# ..          ...                           ...      ...                   ...
# 133  2019-12-06     6:30pm, 6th December 2019   Slight                     1
# 134  2019-12-30    3:28pm, 30th December 2019  Serious                     1
# 135  2020-09-28  12:10pm, 28th September 2020   Slight                     1
# 136  2020-10-02      7:16am, 2nd October 2020  Serious                     1
# 137  2020-12-08     9:30pm, 8th December 2020   Slight                     1
#
#      Number_of_Vehicles   Latitude  Longitude  tavg  Min_temperature_C  \
# 0                     2  51.510986  -0.102536   8.3                4.4
# 1                     2  51.511196  -0.104401   8.3                4.4
# 2                     1  51.511908  -0.103939  19.3               16.0
# 3                     2  51.510995  -0.103112  19.1               16.0
# 4                     2  51.511470  -0.104678   5.8                4.0
# ..                  ...        ...        ...   ...                ...
# 133                   2  51.511124  -0.107082   9.2                7.1
# 134                   2  51.511032  -0.103036   5.8                3.7
# 135                   2  51.512006  -0.104307  11.7                8.4
# 136                   2  51.511075  -0.102386  11.1                9.9
# 137                   2  51.511008  -0.103210   0.9               -0.5
#
#      Max_temperature_C  Daily_precipitation_mm  Snow_depth_mm  Wind_speed_kmh  \
# 0                 13.7                     NaN            NaN            10.2
# 1                 13.7                     NaN            NaN            10.2
# 2                 23.8                     NaN            NaN            10.0
# 3                 22.7                     NaN            NaN            11.6
# 4                  6.9                     NaN            NaN             9.5
# ..                 ...                     ...            ...             ...
# 133               10.8                     1.5            NaN            25.2
# 134                9.5                     0.0            NaN            11.7
# 135               15.8                     0.0            NaN            13.7
# 136               11.8                     3.6            NaN            19.8
# 137                2.3                     3.3            NaN             6.1
#
#      Peak_wind_gust_in_kmh Weather_conditions
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ..                     ...                ...
# 133                   46.3
# 134                   25.9
# 135                   29.6
# 136                   40.8
# 137                   18.5
#
# [138 rows x 15 columns]

# %%
df.drop(columns =['Accident_Index', 'Casualties', 'url', 'apiUrl', 'wdir', 'pres', 'tsun'], axis = 1, inplace=True)

# %%
#save file to avoid runnig all cells

df.to_csv('/Users/kristina/Documents/Velo_python/allweather_data02.csv')

# %%
df = pd.read_csv('/Users/kristina/Documents/Velo_python/allweather_data02.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Date', 'Timestamp', 'Severity',
#        'Number_of_Casualties', 'Number_of_Vehicles', 'Latitude', 'Longitude',
#        'tavg', 'Min_temperature_C', 'Max_temperature_C',
#        'Daily_precipitation_mm', 'Snow_depth_mm', 'Wind_speed_kmh',
#        'Peak_wind_gust_in_kmh', 'Weather_conditions'],
#       dtype='object')

# %%
df.drop(columns =['Unnamed: 0.1', 'Unnamed: 0'], axis = 1, inplace=True)

# %% [markdown]
# After examining the data, I see that the precipitation column contains some NaNs.
#
# I checked the information for those days additionally.
# It seems that on those dates the data was collected by the oldest weather stations in the city, one of which is right in central London.
#
# I believe that if there really was precipitation on those days, the weather stations would have recorded it.
# So I assume in this case that the lack of precipitation data on these days means that there was no precipitation and then I write in the "Weather Conditions" column - "Clear"

# %%
#in percipation NaN - Clear

df.loc[df.Daily_precipitation_mm.isnull(), 'Weather_conditions']='Clear'

# %%
#if percipation less then 3 mm - Clear

df.loc[df.Daily_precipitation_mm <= 3.0, 'Weather_conditions']='Clear'

# %%
#if percipation more then 3 mm - Rain

df.loc[df.Daily_precipitation_mm > 3.0, 'Weather_conditions']='Rain'

# %%
df['Weather_conditions'].count()
# Out:
# 138

# %%
df.loc[df.Daily_precipitation_mm > 0.0].count()
# Out:
# Date                      59
# Timestamp                 59
# Severity                  59
# Number_of_Casualties      59
# Number_of_Vehicles        59
# Latitude                  59
# Longitude                 59
# tavg                      59
# Min_temperature_C         59
# Max_temperature_C         59
# Daily_precipitation_mm    59
# Snow_depth_mm              0
# Wind_speed_kmh            59
# Peak_wind_gust_in_kmh      3
# Weather_conditions        59
# dtype: int64

# %%
df['Snow_depth_mm'].unique()
# Out:
# array([nan, 20.])

# %%
df.loc[df.Snow_depth_mm >=20.0, 'Weather_conditions']='Snow'

# %%
df
# Out:
#            Date                     Timestamp Severity  Number_of_Casualties  \
# 0    2000-03-21       8:06am, 21st March 2000   Slight                     1
# 1    2000-03-21       6:00pm, 21st March 2000   Slight                     1
# 2    2000-07-27        5:58pm, 27th July 2000  Serious                     1
# 3    2000-08-09       1:00pm, 9th August 2000   Slight                     1
# 4    2000-11-20    6:15am, 20th November 2000   Slight                     1
# ..          ...                           ...      ...                   ...
# 133  2019-12-06     6:30pm, 6th December 2019   Slight                     1
# 134  2019-12-30    3:28pm, 30th December 2019  Serious                     1
# 135  2020-09-28  12:10pm, 28th September 2020   Slight                     1
# 136  2020-10-02      7:16am, 2nd October 2020  Serious                     1
# 137  2020-12-08     9:30pm, 8th December 2020   Slight                     1
#
#      Number_of_Vehicles   Latitude  Longitude  tavg  Min_temperature_C  \
# 0                     2  51.510986  -0.102536   8.3                4.4
# 1                     2  51.511196  -0.104401   8.3                4.4
# 2                     1  51.511908  -0.103939  19.3               16.0
# 3                     2  51.510995  -0.103112  19.1               16.0
# 4                     2  51.511470  -0.104678   5.8                4.0
# ..                  ...        ...        ...   ...                ...
# 133                   2  51.511124  -0.107082   9.2                7.1
# 134                   2  51.511032  -0.103036   5.8                3.7
# 135                   2  51.512006  -0.104307  11.7                8.4
# 136                   2  51.511075  -0.102386  11.1                9.9
# 137                   2  51.511008  -0.103210   0.9               -0.5
#
#      Max_temperature_C  Daily_precipitation_mm  Snow_depth_mm  Wind_speed_kmh  \
# 0                 13.7                     NaN            NaN            10.2
# 1                 13.7                     NaN            NaN            10.2
# 2                 23.8                     NaN            NaN            10.0
# 3                 22.7                     NaN            NaN            11.6
# 4                  6.9                     NaN            NaN             9.5
# ..                 ...                     ...            ...             ...
# 133               10.8                     1.5            NaN            25.2
# 134                9.5                     0.0            NaN            11.7
# 135               15.8                     0.0            NaN            13.7
# 136               11.8                     3.6            NaN            19.8
# 137                2.3                     3.3            NaN             6.1
#
#      Peak_wind_gust_in_kmh Weather_conditions
# 0                      NaN              Clear
# 1                      NaN              Clear
# 2                      NaN              Clear
# 3                      NaN              Clear
# 4                      NaN              Clear
# ..                     ...                ...
# 133                   46.3              Clear
# 134                   25.9              Clear
# 135                   29.6              Clear
# 136                   40.8               Rain
# 137                   18.5               Rain
#
# [138 rows x 15 columns]

# %% [markdown]
# To understand what I might consider a windy day, I use data from wikipedia
# https://en.wikipedia.org/wiki/Beaufort_scale
#
# I decide that it is the wind gusts that represent how windy the day was and use that column to estimate the wind.

# %%
df["Wind"] = ""

# %%
df.loc[df.Peak_wind_gust_in_kmh <=19 , 'Wind']=''

# %%
df.loc[df.Peak_wind_gust_in_kmh > 19.1 , 'Wind']= 'Windy'

# %%
df
# Out:
#            Date                     Timestamp Severity  Number_of_Casualties  \
# 0    2000-03-21       8:06am, 21st March 2000   Slight                     1
# 1    2000-03-21       6:00pm, 21st March 2000   Slight                     1
# 2    2000-07-27        5:58pm, 27th July 2000  Serious                     1
# 3    2000-08-09       1:00pm, 9th August 2000   Slight                     1
# 4    2000-11-20    6:15am, 20th November 2000   Slight                     1
# ..          ...                           ...      ...                   ...
# 133  2019-12-06     6:30pm, 6th December 2019   Slight                     1
# 134  2019-12-30    3:28pm, 30th December 2019  Serious                     1
# 135  2020-09-28  12:10pm, 28th September 2020   Slight                     1
# 136  2020-10-02      7:16am, 2nd October 2020  Serious                     1
# 137  2020-12-08     9:30pm, 8th December 2020   Slight                     1
#
#      Number_of_Vehicles   Latitude  Longitude  tavg  Min_temperature_C  \
# 0                     2  51.510986  -0.102536   8.3                4.4
# 1                     2  51.511196  -0.104401   8.3                4.4
# 2                     1  51.511908  -0.103939  19.3               16.0
# 3                     2  51.510995  -0.103112  19.1               16.0
# 4                     2  51.511470  -0.104678   5.8                4.0
# ..                  ...        ...        ...   ...                ...
# 133                   2  51.511124  -0.107082   9.2                7.1
# 134                   2  51.511032  -0.103036   5.8                3.7
# 135                   2  51.512006  -0.104307  11.7                8.4
# 136                   2  51.511075  -0.102386  11.1                9.9
# 137                   2  51.511008  -0.103210   0.9               -0.5
#
#      Max_temperature_C  Daily_precipitation_mm  Snow_depth_mm  Wind_speed_kmh  \
# 0                 13.7                     NaN            NaN            10.2
# 1                 13.7                     NaN            NaN            10.2
# 2                 23.8                     NaN            NaN            10.0
# 3                 22.7                     NaN            NaN            11.6
# 4                  6.9                     NaN            NaN             9.5
# ..                 ...                     ...            ...             ...
# 133               10.8                     1.5            NaN            25.2
# 134                9.5                     0.0            NaN            11.7
# 135               15.8                     0.0            NaN            13.7
# 136               11.8                     3.6            NaN            19.8
# 137                2.3                     3.3            NaN             6.1
#
#      Peak_wind_gust_in_kmh Weather_conditions   Wind Road_conditions
# 0                      NaN              Clear                    Dry
# 1                      NaN              Clear                    Dry
# 2                      NaN              Clear                    Dry
# 3                      NaN              Clear                    Dry
# 4                      NaN              Clear                    Dry
# ..                     ...                ...    ...             ...
# 133                   46.3              Clear  Windy             Dry
# 134                   25.9              Clear  Windy             Dry
# 135                   29.6              Clear  Windy             Dry
# 136                   40.8               Rain  Windy             Wet
# 137                   18.5               Rain                  Frost
#
# [138 rows x 17 columns]

# %% [markdown]
# I'm trying to fill road condition data based on the information I have.
#
# On clear days I write "Dry", on rainy days I write "Wet", on days when the air temperature was near zero and below, I write "Frost"
#
# Of course, these are my assumptions, but as a part of my learning, I want to fill in these values and see the visualization.

# %%
#'Snow', 'Wet', 'Dry', 'Frost', 'Flood'

df["Road_conditions"] = ""

# %%
df.loc[df.Weather_conditions == "Clear" , 'Road_conditions']= 'Dry'

# %%
df.loc[df.Weather_conditions == "Rain" , 'Road_conditions']= 'Wet'

# %%
df.loc[df.Weather_conditions == "Snow" , 'Road_conditions']= 'Snow'

# %%
df.loc[df.Min_temperature_C <=0 , 'Road_conditions']= 'Frost'

# %%
#joining two string columns with a space and save some more solutions as a comment
#[''.join(i) for i in zip(df["Weather_conditions"].map(str),df["Wind"])] <150
#df['Weather_conditions'].astype(str) + df['Wind'] > 150 rows

df['Weather_conditions_'] = df[['Weather_conditions', 'Wind']].agg(' '.join, axis=1)

# %%
df
# Out:
#            Date                     Timestamp Severity  Number_of_Casualties  \
# 0    2000-03-21       8:06am, 21st March 2000   Slight                     1
# 1    2000-03-21       6:00pm, 21st March 2000   Slight                     1
# 2    2000-07-27        5:58pm, 27th July 2000  Serious                     1
# 3    2000-08-09       1:00pm, 9th August 2000   Slight                     1
# 4    2000-11-20    6:15am, 20th November 2000   Slight                     1
# ..          ...                           ...      ...                   ...
# 133  2019-12-06     6:30pm, 6th December 2019   Slight                     1
# 134  2019-12-30    3:28pm, 30th December 2019  Serious                     1
# 135  2020-09-28  12:10pm, 28th September 2020   Slight                     1
# 136  2020-10-02      7:16am, 2nd October 2020  Serious                     1
# 137  2020-12-08     9:30pm, 8th December 2020   Slight                     1
#
#      Number_of_Vehicles   Latitude  Longitude  tavg  Min_temperature_C  \
# 0                     2  51.510986  -0.102536   8.3                4.4
# 1                     2  51.511196  -0.104401   8.3                4.4
# 2                     1  51.511908  -0.103939  19.3               16.0
# 3                     2  51.510995  -0.103112  19.1               16.0
# 4                     2  51.511470  -0.104678   5.8                4.0
# ..                  ...        ...        ...   ...                ...
# 133                   2  51.511124  -0.107082   9.2                7.1
# 134                   2  51.511032  -0.103036   5.8                3.7
# 135                   2  51.512006  -0.104307  11.7                8.4
# 136                   2  51.511075  -0.102386  11.1                9.9
# 137                   2  51.511008  -0.103210   0.9               -0.5
#
#      Max_temperature_C  Daily_precipitation_mm  Snow_depth_mm  Wind_speed_kmh  \
# 0                 13.7                     NaN            NaN            10.2
# 1                 13.7                     NaN            NaN            10.2
# 2                 23.8                     NaN            NaN            10.0
# 3                 22.7                     NaN            NaN            11.6
# 4                  6.9                     NaN            NaN             9.5
# ..                 ...                     ...            ...             ...
# 133               10.8                     1.5            NaN            25.2
# 134                9.5                     0.0            NaN            11.7
# 135               15.8                     0.0            NaN            13.7
# 136               11.8                     3.6            NaN            19.8
# 137                2.3                     3.3            NaN             6.1
#
#      Peak_wind_gust_in_kmh Weather_conditions   Wind Road_conditions  \
# 0                      NaN              Clear                    Dry
# 1                      NaN              Clear                    Dry
# 2                      NaN              Clear                    Dry
# 3                      NaN              Clear                    Dry
# 4                      NaN              Clear                    Dry
# ..                     ...                ...    ...             ...
# 133                   46.3              Clear  Windy             Dry
# 134                   25.9              Clear  Windy             Dry
# 135                   29.6              Clear  Windy             Dry
# 136                   40.8               Rain  Windy             Wet
# 137                   18.5               Rain                  Frost
#
#     Weather_conditions_
# 0                Clear
# 1                Clear
# 2                Clear
# 3                Clear
# 4                Clear
# ..                  ...
# 133         Clear Windy
# 134         Clear Windy
# 135         Clear Windy
# 136          Rain Windy
# 137               Rain
#
# [138 rows x 18 columns]

# %%
#save to csv to avoid running sells from above if I need to update something

df.to_csv('/Users/kristina/Documents/Velo_python/allweather_data03.csv')

# %%
df = pd.read_csv ('/Users/kristina/Documents/Velo_python/allweather_data03.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Timestamp', 'Severity', 'Number_of_Casualties',
#        'Number_of_Vehicles', 'Latitude', 'Longitude', 'tavg',
#        'Min_temperature_C', 'Max_temperature_C', 'Daily_precipitation_mm',
#        'Snow_depth_mm', 'Wind_speed_kmh', 'Peak_wind_gust_in_kmh',
#        'Weather_conditions', 'Wind', 'Road_conditions', 'Weather_conditions_'],
#       dtype='object')

# %%
df.drop(columns =['Unnamed: 0', 'tavg', 'Snow_depth_mm', 'Wind_speed_kmh', 'Peak_wind_gust_in_kmh', 'Weather_conditions', 'Wind'], axis = 1, inplace=True)

# %%
df
# Out:
#            Date                     Timestamp Severity  Number_of_Casualties  \
# 0    2000-03-21       8:06am, 21st March 2000   Slight                     1
# 1    2000-03-21       6:00pm, 21st March 2000   Slight                     1
# 2    2000-07-27        5:58pm, 27th July 2000  Serious                     1
# 3    2000-08-09       1:00pm, 9th August 2000   Slight                     1
# 4    2000-11-20    6:15am, 20th November 2000   Slight                     1
# ..          ...                           ...      ...                   ...
# 133  2019-12-06     6:30pm, 6th December 2019   Slight                     1
# 134  2019-12-30    3:28pm, 30th December 2019  Serious                     1
# 135  2020-09-28  12:10pm, 28th September 2020   Slight                     1
# 136  2020-10-02      7:16am, 2nd October 2020  Serious                     1
# 137  2020-12-08     9:30pm, 8th December 2020   Slight                     1
#
#      Number_of_Vehicles   Latitude  Longitude  Min_temperature_C  \
# 0                     2  51.510986  -0.102536                4.4
# 1                     2  51.511196  -0.104401                4.4
# 2                     1  51.511908  -0.103939               16.0
# 3                     2  51.510995  -0.103112               16.0
# 4                     2  51.511470  -0.104678                4.0
# ..                  ...        ...        ...                ...
# 133                   2  51.511124  -0.107082                7.1
# 134                   2  51.511032  -0.103036                3.7
# 135                   2  51.512006  -0.104307                8.4
# 136                   2  51.511075  -0.102386                9.9
# 137                   2  51.511008  -0.103210               -0.5
#
#      Max_temperature_C  Daily_precipitation_mm Road_conditions  \
# 0                 13.7                     NaN             Dry
# 1                 13.7                     NaN             Dry
# 2                 23.8                     NaN             Dry
# 3                 22.7                     NaN             Dry
# 4                  6.9                     NaN             Dry
# ..                 ...                     ...             ...
# 133               10.8                     1.5             Dry
# 134                9.5                     0.0             Dry
# 135               15.8                     0.0             Dry
# 136               11.8                     3.6             Wet
# 137                2.3                     3.3           Frost
#
#     Weather_conditions_
# 0                Clear
# 1                Clear
# 2                Clear
# 3                Clear
# 4                Clear
# ..                  ...
# 133         Clear Windy
# 134         Clear Windy
# 135         Clear Windy
# 136          Rain Windy
# 137               Rain
#
# [138 rows x 12 columns]

# %%
df['Month'] = pd.to_datetime(df['Date']).dt.month

# %%
df['Day'] = pd.to_datetime(df['Timestamp']).dt.day_name()

# %%
df['Time'] = pd.to_datetime(df['Timestamp']).dt.time

# %%
season = {
            12:'Winter', 1:'Winter', 2:'Winter',
            3:'Spring', 4:'Spring', 5:'Spring',
            6:'Summer', 7:'Summer', 8:'Summer',
            9:'Autumn', 10:'Autumn', 11:'Autumn'}

# %%
df['Season'] = df['Month'].apply(lambda x: season[x])

# %%
Precipation_0_1 = {
            'Rain ':1, 'Snow ':1, 'Fog':1,
            'Clear ': 0, 'Clear Windy': 0, 'Rain Windy':1,
           'Snow Windy':1}

# %%
df['Precipation_0_1'] = df['Weather_conditions_'].apply(lambda x: Precipation_0_1[x])

# %%
df['Month'] = pd.to_datetime(df['Timestamp']).dt.month_name()

# %%
df
# Out:
#            Date                     Timestamp Severity  Number_of_Casualties  \
# 0    2000-03-21       8:06am, 21st March 2000   Slight                     1
# 1    2000-03-21       6:00pm, 21st March 2000   Slight                     1
# 2    2000-07-27        5:58pm, 27th July 2000  Serious                     1
# 3    2000-08-09       1:00pm, 9th August 2000   Slight                     1
# 4    2000-11-20    6:15am, 20th November 2000   Slight                     1
# ..          ...                           ...      ...                   ...
# 133  2019-12-06     6:30pm, 6th December 2019   Slight                     1
# 134  2019-12-30    3:28pm, 30th December 2019  Serious                     1
# 135  2020-09-28  12:10pm, 28th September 2020   Slight                     1
# 136  2020-10-02      7:16am, 2nd October 2020  Serious                     1
# 137  2020-12-08     9:30pm, 8th December 2020   Slight                     1
#
#      Number_of_Vehicles   Latitude  Longitude  Min_temperature_C  \
# 0                     2  51.510986  -0.102536                4.4
# 1                     2  51.511196  -0.104401                4.4
# 2                     1  51.511908  -0.103939               16.0
# 3                     2  51.510995  -0.103112               16.0
# 4                     2  51.511470  -0.104678                4.0
# ..                  ...        ...        ...                ...
# 133                   2  51.511124  -0.107082                7.1
# 134                   2  51.511032  -0.103036                3.7
# 135                   2  51.512006  -0.104307                8.4
# 136                   2  51.511075  -0.102386                9.9
# 137                   2  51.511008  -0.103210               -0.5
#
#      Max_temperature_C  Daily_precipitation_mm Road_conditions  \
# 0                 13.7                     NaN             Dry
# 1                 13.7                     NaN             Dry
# 2                 23.8                     NaN             Dry
# 3                 22.7                     NaN             Dry
# 4                  6.9                     NaN             Dry
# ..                 ...                     ...             ...
# 133               10.8                     1.5             Dry
# 134                9.5                     0.0             Dry
# 135               15.8                     0.0             Dry
# 136               11.8                     3.6             Wet
# 137                2.3                     3.3           Frost
#
#     Weather_conditions_      Month        Day      Time  Season  \
# 0                Clear       March    Tuesday  08:06:00  Spring
# 1                Clear       March    Tuesday  18:00:00  Spring
# 2                Clear        July   Thursday  17:58:00  Summer
# 3                Clear      August  Wednesday  13:00:00  Summer
# 4                Clear    November     Monday  06:15:00  Autumn
# ..                  ...        ...        ...       ...     ...
# 133         Clear Windy   December     Friday  18:30:00  Winter
# 134         Clear Windy   December     Monday  15:28:00  Winter
# 135         Clear Windy  September     Monday  12:10:00  Autumn
# 136          Rain Windy    October     Friday  07:16:00  Autumn
# 137               Rain    December    Tuesday  21:30:00  Winter
#
#      Precipation_0_1
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ..               ...
# 133                0
# 134                0
# 135                0
# 136                1
# 137                1
#
# [138 rows x 17 columns]

# %%
#save to csv to avoid running sells from above if I need to update something

df.to_csv('/Users/kristina/Documents/Velo_python/allweather_data04.csv')

# %%
df = pd.read_csv ('/Users/kristina/Documents/Velo_python/allweather_data04.csv')

# %%
workingdays = {
           'Monday':'working_day', 
           'Tuesday':'working_day', 
           'Wednesday':'working_day',
            'Thursday':'working_day', 
            'Friday':'pre_weekend', 
            'Saturday':'weekend',
            'Sunday':'weekend'}

# %%
df['Working_days'] = df['Day'].apply(lambda x: workingdays[x])

# %%
df
# Out:
#      Unnamed: 0        Date                     Timestamp Severity  \
# 0             0  2000-03-21       8:06am, 21st March 2000   Slight
# 1             1  2000-03-21       6:00pm, 21st March 2000   Slight
# 2             2  2000-07-27        5:58pm, 27th July 2000  Serious
# 3             3  2000-08-09       1:00pm, 9th August 2000   Slight
# 4             4  2000-11-20    6:15am, 20th November 2000   Slight
# ..          ...         ...                           ...      ...
# 133         133  2019-12-06     6:30pm, 6th December 2019   Slight
# 134         134  2019-12-30    3:28pm, 30th December 2019  Serious
# 135         135  2020-09-28  12:10pm, 28th September 2020   Slight
# 136         136  2020-10-02      7:16am, 2nd October 2020  Serious
# 137         137  2020-12-08     9:30pm, 8th December 2020   Slight
#
#      Number_of_Casualties  Number_of_Vehicles   Latitude  Longitude  \
# 0                       1                   2  51.510986  -0.102536
# 1                       1                   2  51.511196  -0.104401
# 2                       1                   1  51.511908  -0.103939
# 3                       1                   2  51.510995  -0.103112
# 4                       1                   2  51.511470  -0.104678
# ..                    ...                 ...        ...        ...
# 133                     1                   2  51.511124  -0.107082
# 134                     1                   2  51.511032  -0.103036
# 135                     1                   2  51.512006  -0.104307
# 136                     1                   2  51.511075  -0.102386
# 137                     1                   2  51.511008  -0.103210
#
#      Min_temperature_C  Max_temperature_C  Daily_precipitation_mm  \
# 0                  4.4               13.7                     NaN
# 1                  4.4               13.7                     NaN
# 2                 16.0               23.8                     NaN
# 3                 16.0               22.7                     NaN
# 4                  4.0                6.9                     NaN
# ..                 ...                ...                     ...
# 133                7.1               10.8                     1.5
# 134                3.7                9.5                     0.0
# 135                8.4               15.8                     0.0
# 136                9.9               11.8                     3.6
# 137               -0.5                2.3                     3.3
#
#     Road_conditions Weather_conditions_      Month        Day      Time  \
# 0               Dry              Clear       March    Tuesday  08:06:00
# 1               Dry              Clear       March    Tuesday  18:00:00
# 2               Dry              Clear        July   Thursday  17:58:00
# 3               Dry              Clear      August  Wednesday  13:00:00
# 4               Dry              Clear    November     Monday  06:15:00
# ..              ...                 ...        ...        ...       ...
# 133             Dry         Clear Windy   December     Friday  18:30:00
# 134             Dry         Clear Windy   December     Monday  15:28:00
# 135             Dry         Clear Windy  September     Monday  12:10:00
# 136             Wet          Rain Windy    October     Friday  07:16:00
# 137           Frost               Rain    December    Tuesday  21:30:00
#
#      Season  Precipation_0_1 Working_days
# 0    Spring                0  working_day
# 1    Spring                0  working_day
# 2    Summer                0  working_day
# 3    Summer                0  working_day
# 4    Autumn                0  working_day
# ..      ...              ...          ...
# 133  Winter                0  pre_weekend
# 134  Winter                0  working_day
# 135  Autumn                0  working_day
# 136  Autumn                1  pre_weekend
# 137  Winter                1  working_day
#
# [138 rows x 19 columns]

# %% [markdown]
# For more granular data,
# I processed the data from the timestamp to get
# the names of the months,
# the names of the days,
# the names of the seasons,
# whether there was precipitation on this day or not,
# and whether it was a working day, weekend or Friday (I called it pre-weekend, because Friday has its own specifics in people's lives)

# %% [markdown]
# Now I want to remove unnecessary columns and save a file with data that I will need for visualization

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Timestamp', 'Severity', 'Number_of_Casualties',
#        'Number_of_Vehicles', 'Latitude', 'Longitude', 'Min_temperature_C',
#        'Max_temperature_C', 'Daily_precipitation_mm', 'Road_conditions',
#        'Weather_conditions_', 'Month', 'Day', 'Time', 'Season',
#        'Precipation_0_1', 'Working_days'],
#       dtype='object')

# %%
df.drop(columns =['Unnamed: 0', 'Min_temperature_C', 'Max_temperature_C', 
                  'Daily_precipitation_mm'], axis = 1, inplace=True)

# %%
df
# Out:
#            Date                     Timestamp Severity  Number_of_Casualties  \
# 0    2000-03-21       8:06am, 21st March 2000   Slight                     1
# 1    2000-03-21       6:00pm, 21st March 2000   Slight                     1
# 2    2000-07-27        5:58pm, 27th July 2000  Serious                     1
# 3    2000-08-09       1:00pm, 9th August 2000   Slight                     1
# 4    2000-11-20    6:15am, 20th November 2000   Slight                     1
# ..          ...                           ...      ...                   ...
# 133  2019-12-06     6:30pm, 6th December 2019   Slight                     1
# 134  2019-12-30    3:28pm, 30th December 2019  Serious                     1
# 135  2020-09-28  12:10pm, 28th September 2020   Slight                     1
# 136  2020-10-02      7:16am, 2nd October 2020  Serious                     1
# 137  2020-12-08     9:30pm, 8th December 2020   Slight                     1
#
#      Number_of_Vehicles   Latitude  Longitude Road_conditions  \
# 0                     2  51.510986  -0.102536             Dry
# 1                     2  51.511196  -0.104401             Dry
# 2                     1  51.511908  -0.103939             Dry
# 3                     2  51.510995  -0.103112             Dry
# 4                     2  51.511470  -0.104678             Dry
# ..                  ...        ...        ...             ...
# 133                   2  51.511124  -0.107082             Dry
# 134                   2  51.511032  -0.103036             Dry
# 135                   2  51.512006  -0.104307             Dry
# 136                   2  51.511075  -0.102386             Wet
# 137                   2  51.511008  -0.103210           Frost
#
#     Weather_conditions_      Month        Day      Time  Season  \
# 0                Clear       March    Tuesday  08:06:00  Spring
# 1                Clear       March    Tuesday  18:00:00  Spring
# 2                Clear        July   Thursday  17:58:00  Summer
# 3                Clear      August  Wednesday  13:00:00  Summer
# 4                Clear    November     Monday  06:15:00  Autumn
# ..                  ...        ...        ...       ...     ...
# 133         Clear Windy   December     Friday  18:30:00  Winter
# 134         Clear Windy   December     Monday  15:28:00  Winter
# 135         Clear Windy  September     Monday  12:10:00  Autumn
# 136          Rain Windy    October     Friday  07:16:00  Autumn
# 137               Rain    December    Tuesday  21:30:00  Winter
#
#      Precipation_0_1 Working_days
# 0                  0  working_day
# 1                  0  working_day
# 2                  0  working_day
# 3                  0  working_day
# 4                  0  working_day
# ..               ...          ...
# 133                0  pre_weekend
# 134                0  working_day
# 135                0  working_day
# 136                1  pre_weekend
# 137                1  working_day
#
# [138 rows x 15 columns]

# %%
#save to csv
df.to_csv('/Users/kristina/Documents/Velo_python/london_data_clean.csv', index=False)

# %%
df = pd.read_csv ('/Users/kristina/Documents/Velo_python/london_data_clean.csv')

# %%
df
# Out:
#            Date                     Timestamp Severity  Number_of_Casualties  \
# 0    2000-03-21       8:06am, 21st March 2000   Slight                     1
# 1    2000-03-21       6:00pm, 21st March 2000   Slight                     1
# 2    2000-07-27        5:58pm, 27th July 2000  Serious                     1
# 3    2000-08-09       1:00pm, 9th August 2000   Slight                     1
# 4    2000-11-20    6:15am, 20th November 2000   Slight                     1
# ..          ...                           ...      ...                   ...
# 133  2019-12-06     6:30pm, 6th December 2019   Slight                     1
# 134  2019-12-30    3:28pm, 30th December 2019  Serious                     1
# 135  2020-09-28  12:10pm, 28th September 2020   Slight                     1
# 136  2020-10-02      7:16am, 2nd October 2020  Serious                     1
# 137  2020-12-08     9:30pm, 8th December 2020   Slight                     1
#
#      Number_of_Vehicles   Latitude  Longitude Road_conditions  \
# 0                     2  51.510986  -0.102536             Dry
# 1                     2  51.511196  -0.104401             Dry
# 2                     1  51.511908  -0.103939             Dry
# 3                     2  51.510995  -0.103112             Dry
# 4                     2  51.511470  -0.104678             Dry
# ..                  ...        ...        ...             ...
# 133                   2  51.511124  -0.107082             Dry
# 134                   2  51.511032  -0.103036             Dry
# 135                   2  51.512006  -0.104307             Dry
# 136                   2  51.511075  -0.102386             Wet
# 137                   2  51.511008  -0.103210           Frost
#
#     Weather_conditions_      Month        Day      Time  Season  \
# 0                Clear       March    Tuesday  08:06:00  Spring
# 1                Clear       March    Tuesday  18:00:00  Spring
# 2                Clear        July   Thursday  17:58:00  Summer
# 3                Clear      August  Wednesday  13:00:00  Summer
# 4                Clear    November     Monday  06:15:00  Autumn
# ..                  ...        ...        ...       ...     ...
# 133         Clear Windy   December     Friday  18:30:00  Winter
# 134         Clear Windy   December     Monday  15:28:00  Winter
# 135         Clear Windy  September     Monday  12:10:00  Autumn
# 136          Rain Windy    October     Friday  07:16:00  Autumn
# 137               Rain    December    Tuesday  21:30:00  Winter
#
#      Precipation_0_1 Working_days
# 0                  0  working_day
# 1                  0  working_day
# 2                  0  working_day
# 3                  0  working_day
# 4                  0  working_day
# ..               ...          ...
# 133                0  pre_weekend
# 134                0  working_day
# 135                0  working_day
# 136                1  pre_weekend
# 137                1  working_day
#
# [138 rows x 15 columns]

# %% [markdown]
# Final check

# %%
df.isnull().count()
# Out:
# Date                    138
# Timestamp               138
# Severity                138
# Number_of_Casualties    138
# Number_of_Vehicles      138
# Latitude                138
# Longitude               138
# Road_conditions         138
# Weather_conditions_     138
# Month                   138
# Day                     138
# Time                    138
# Season                  138
# Precipation_0_1         138
# Working_days            138
# dtype: int64
